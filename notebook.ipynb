# %%
import pandas as pd
import plotly.express as px
from dash import Dash, html, dcc, Input, Output, State
import dash_bootstrap_components as dbc
from dash_bootstrap_templates import load_figure_template
from jupyter_dash import JupyterDash
from datetime import datetime, date
import requests
load_figure_template("flatly")
dbc_css = "https://cdn.jsdelivr.net/gh/AnnMarieW/dash-bootstrap-templates/dbc.min.css"

# %%
locations_r = requests.get('https://api.ipma.pt/open-data/distrits-islands.json')

# %%
locations_dict = locations_r.json()

# %%
locations_dict.keys()
# Out:
# dict_keys(['owner', 'country', 'data'])

# %%
locals_df = pd.DataFrame(locations_dict['data'])
locals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   idRegiao       35 non-null     int64
#  1   idAreaAviso    35 non-null     object
#  2   idConcelho     35 non-null     int64
#  3   globalIdLocal  35 non-null     int64
#  4   latitude       35 non-null     object
#  5   idDistrito     35 non-null     int64
#  6   local          35 non-null     object
#  7   longitude      35 non-null     object
# dtypes: int64(4), object(4)
# memory usage: 2.3+ KB

# %%
coordinates = ['latitude', 'longitude']
locals_df[coordinates] = locals_df[coordinates].astype('float64')
locals_df.head()
# Out:
#    idRegiao idAreaAviso  idConcelho  globalIdLocal  latitude  idDistrito  \
# 0         1         AVR           5        1010500   40.6413           1
# 1         1         BJA           5        1020500   38.0200           2
# 2         1         BRG           3        1030300   41.5475           3
# 3         1         BRG           8        1030800   41.4434           3
# 4         1         BGC           2        1040200   41.8076           4
#
#        local  longitude
# 0     Aveiro    -8.6535
# 1       Beja    -7.8700
# 2      Braga    -8.4227
# 3  Guimarães    -8.2938
# 4   Bragança    -6.7606

# %%
global_local_id = list(locals_df['globalIdLocal'])

# %%
forecast_r = requests.get(f'https://api.ipma.pt/open-data/forecast/meteorology/cities/daily/{global_local_id[0]}.json')
forecast_dict = forecast_r.json()

# %%
forecast_dict.keys()
# Out:
# dict_keys(['owner', 'country', 'data', 'globalIdLocal', 'dataUpdate'])

# %%
pd.DataFrame(forecast_dict['data'])
# Out:
#   precipitaProb  tMin  tMax predWindDir  idWeatherType  classWindSpeed  \
# 0         100.0  14.4  16.4           S              9               2
# 1         100.0  14.1  17.6          SW              6               2
# 2          86.0  13.5  17.6           S             10               2
# 3         100.0  14.1  17.9          SW              9               1
# 4          27.0  13.2  18.4           S              3               2
#
#   longitude forecastDate  classPrecInt latitude
# 0   -8.6535   2023-03-08           2.0  40.6413
# 1   -8.6535   2023-03-09           2.0  40.6413
# 2   -8.6535   2023-03-10           1.0  40.6413
# 3   -8.6535   2023-03-11           2.0  40.6413
# 4   -8.6535   2023-03-12           NaN  40.6413

# %%
id_stations_r = requests.get('https://api.ipma.pt/open-data/observation/meteorology/stations/stations.json')

# %%
id_stations_dict = id_stations_r.json()
id_stations_dict[0]
# Out:
# {'geometry': {'type': 'Point', 'coordinates': [-7.821, 37.033]},
#  'type': 'Feature',
#  'properties': {'idEstacao': 1210881, 'localEstacao': 'Olhão, EPPO'}}

# %%
id_stations_list = [station['properties'] for station in id_stations_dict]
id_stations_list[:5]
# Out:
# [{'idEstacao': 1210881, 'localEstacao': 'Olhão, EPPO'},
#  {'idEstacao': 1210883, 'localEstacao': 'Tavira'},
#  {'idEstacao': 11217430,
#   'localEstacao': 'Graciosa / Serra das Fontes (DROTRH)'},
#  {'idEstacao': 6212121, 'localEstacao': 'Terras de Bouro/Barral (CIM)'},
#  {'idEstacao': 6212122, 'localEstacao': 'Amares Caldelas (CIM)'}]

# %%
idstations_df = pd.DataFrame(id_stations_list)
idstations_df.head()
# Out:
#    idEstacao                          localEstacao
# 0    1210881                           Olhão, EPPO
# 1    1210883                                Tavira
# 2   11217430  Graciosa / Serra das Fontes (DROTRH)
# 3    6212121          Terras de Bouro/Barral (CIM)
# 4    6212122                 Amares Caldelas (CIM)

# %%
coordinates_stations = [station['geometry']['coordinates'] for station in id_stations_dict]
coordinates_stations[:5]
# Out:
# [[-7.821, 37.033],
#  [-7.62050375, 37.12166968],
#  [-28.0038, 39.0672],
#  [-8.31808611, 41.70225278],
#  [-8.37977778, 41.66796389]]

# %%
idstations_df = pd.concat([idstations_df, pd.DataFrame(coordinates_stations)],
                          axis=1)
idstations_df.head()
# Out:
#    idEstacao                          localEstacao          0          1
# 0    1210881                           Olhão, EPPO  -7.821000  37.033000
# 1    1210883                                Tavira  -7.620504  37.121670
# 2   11217430  Graciosa / Serra das Fontes (DROTRH) -28.003800  39.067200
# 3    6212121          Terras de Bouro/Barral (CIM)  -8.318086  41.702253
# 4    6212122                 Amares Caldelas (CIM)  -8.379778  41.667964

# %%
idstations_df.columns = ['id', 'local', 'lon', 'lat']
idstations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      197 non-null    int64
#  1   local   197 non-null    object
#  2   lon     197 non-null    float64
#  3   lat     197 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 6.3+ KB

# %%
idstations_df.sort_values('local', inplace=True)
# idstations_df.to_csv('./data/idstations.csv')

# %%
idstations_df[idstations_df['local'].str.contains('Lisboa')]
# Out:
#           id                     local       lon        lat
# 167  1200579       Lisboa (G.Coutinho) -9.127494  38.766203
# 135  1200535        Lisboa (Geofísico) -9.149722  38.719078
# 47   7240919  Lisboa, Amoreiras (LFCL) -9.164900  38.723900
# 86   1210762   Lisboa, Tapada da Ajuda -9.182825  38.709561

# %%
map = px.scatter_mapbox(idstations_df, lon='lon', lat='lat', 
                        center=dict(lon=-7.821000, lat=37.033000),
                        zoom=11, mapbox_style='carto-positron')
map.update_traces(marker_color='red', marker_size=8)
map.show()

# %%
obs_meteo = requests.get('https://api.ipma.pt/open-data/observation/meteorology/stations/observations.json')

# %%
obs_dict = obs_meteo.json()
obs_dict
# Out:
# {'2023-03-09T01:00': {'1210881': {'intensidadeVentoKM': 8.6,
#    'temperatura': 16.5,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.4,
#    'humidade': 94.0,
#    'pressao': 1017.7},
#   '1210883': {'intensidadeVentoKM': 8.3,
#    'temperatura': 15.9,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.3,
#    'humidade': 95.0,
#    'pressao': 1018.6},
#   '1210865': None,
#   '11217430': {'intensidadeVentoKM': 18.7,
#    'temperatura': 14.6,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.2,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6212121': {'intensidadeVentoKM': 12.2,
#    'temperatura': 12.6,
#    'radiacao': 6.6,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.4,
#    'humidade': 92.0,
#    'pressao': 1009.0},
#   '6212122': {'intensidadeVentoKM': 6.5,
#    'temperatura': 13.9,
#    'radiacao': 3.6,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.8,
#    'humidade': 93.0,
#    'pressao': 1011.1},
#   '1210907': None,
#   '6212124': {'intensidadeVentoKM': 13.3,
#    'temperatura': 13.3,
#    'radiacao': 3.6,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.7,
#    'humidade': 96.0,
#    'pressao': 1011.6},
#   '6212125': None,
#   '6212126': {'intensidadeVentoKM': 14.8,
#    'temperatura': 14.4,
#    'radiacao': 3.6,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.1,
#    'humidade': 96.0,
#    'pressao': 1010.7},
#   '1200560': {'intensidadeVentoKM': 7.2,
#    'temperatura': 11.5,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.0,
#    'humidade': 100.0,
#    'pressao': 1012.4},
#   '1240610': {'intensidadeVentoKM': -99.0,
#    'temperatura': 14.2,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 98.0,
#    'pressao': -99.0},
#   '1210867': {'intensidadeVentoKM': 13.3,
#    'temperatura': 16.2,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210632': {'intensidadeVentoKM': 1.4,
#    'temperatura': 10.6,
#    'radiacao': -99.0,
#    'idDireccVento': 9,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.4,
#    'humidade': 90.0,
#    'pressao': -99.0},
#   '1210932': {'intensidadeVentoKM': 10.4,
#    'temperatura': 16.6,
#    'radiacao': -99.0,
#    'idDireccVento': 4,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 2.9,
#    'humidade': 78.0,
#    'pressao': -99.0},
#   '1210747': {'intensidadeVentoKM': -99.0,
#    'temperatura': 16.6,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.2,
#    'intensidadeVento': -99.0,
#    'humidade': 98.0,
#    'pressao': -99.0},
#   '1200535': {'intensidadeVentoKM': 33.8,
#    'temperatura': 16.1,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 9.4,
#    'humidade': 100.0,
#    'pressao': 1013.9},
#   '1210721': {'intensidadeVentoKM': 31.3,
#    'temperatura': 14.0,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.2,
#    'intensidadeVento': 8.7,
#    'humidade': 98.0,
#    'pressao': -99.0},
#   '1210956': {'intensidadeVentoKM': 10.8,
#    'temperatura': 19.9,
#    'radiacao': 0.0,
#    'idDireccVento': 9,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.0,
#    'humidade': 79.0,
#    'pressao': -99.0},
#   '1210637': {'intensidadeVentoKM': 13.3,
#    'temperatura': 10.7,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.7,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210960': {'intensidadeVentoKM': 5.8,
#    'temperatura': 17.2,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.6,
#    'humidade': 89.0,
#    'pressao': 1019.7},
#   '1210965': {'intensidadeVentoKM': -99.0,
#    'temperatura': 14.6,
#    'radiacao': 0.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 85.0,
#    'pressao': -99.0},
#   '1210967': {'intensidadeVentoKM': -99.0,
#    'temperatura': 16.6,
#    'radiacao': 0.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 85.0,
#    'pressao': -99.0},
#   '1210970': {'intensidadeVentoKM': -99.0,
#    'temperatura': 8.8,
#    'radiacao': 2.9,
#    'idDireccVento': 0,
#    'precAcumulada': 0.1,
#    'intensidadeVento': -99.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210972': {'intensidadeVentoKM': 11.2,
#    'temperatura': 11.6,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.1,
#    'humidade': 94.0,
#    'pressao': -99.0},
#   '1210973': {'intensidadeVentoKM': 27.7,
#    'temperatura': 8.8,
#    'radiacao': 0.0,
#    'idDireccVento': 8,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.7,
#    'humidade': 91.0,
#    'pressao': -99.0},
#   '1210974': {'intensidadeVentoKM': -99.0,
#    'temperatura': 6.8,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210975': {'intensidadeVentoKM': -99.0,
#    'temperatura': 12.1,
#    'radiacao': 184.9,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1210976': {'intensidadeVentoKM': 2.2,
#    'temperatura': 14.8,
#    'radiacao': 0.6,
#    'idDireccVento': 8,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.6,
#    'humidade': 91.0,
#    'pressao': -99.0},
#   '1210977': {'intensidadeVentoKM': 4.7,
#    'temperatura': 17.2,
#    'radiacao': 0.0,
#    'idDireccVento': 9,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.3,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1210978': {'intensidadeVentoKM': 4.3,
#    'temperatura': 18.2,
#    'radiacao': 0.0,
#    'idDireccVento': 9,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.2,
#    'humidade': 88.0,
#    'pressao': -99.0},
#   '1240675': {'intensidadeVentoKM': -99.0,
#    'temperatura': 13.1,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1210980': {'intensidadeVentoKM': 31.7,
#    'temperatura': 13.1,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 8.8,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '11217510': {'intensidadeVentoKM': 42.8,
#    'temperatura': 10.8,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 11.9,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210984': {'intensidadeVentoKM': -99.0,
#    'temperatura': 16.0,
#    'radiacao': 1.8,
#    'idDireccVento': 0,
#    'precAcumulada': 0.2,
#    'intensidadeVento': -99.0,
#    'humidade': 94.0,
#    'pressao': -99.0},
#   '1210986': {'intensidadeVentoKM': 6.5,
#    'temperatura': 19.1,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.8,
#    'humidade': 86.0,
#    'pressao': 1019.5},
#   '1210987': {'intensidadeVentoKM': 8.3,
#    'temperatura': 15.0,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.3,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210990': {'intensidadeVentoKM': 10.4,
#    'temperatura': 16.6,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.9,
#    'humidade': 96.0,
#    'pressao': 1019.7},
#   '1200571': {'intensidadeVentoKM': 9.0,
#    'temperatura': 12.9,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.5,
#    'humidade': 100.0,
#    'pressao': 1014.4},
#   '5210758': {'intensidadeVentoKM': 20.5,
#    'temperatura': 16.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.5,
#    'intensidadeVento': 5.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210513': {'intensidadeVentoKM': 13.7,
#    'temperatura': 16.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.8,
#    'humidade': 93.0,
#    'pressao': -99.0},
#   '1210520': None,
#   '6212123': {'intensidadeVentoKM': 1.4,
#    'temperatura': 14.0,
#    'radiacao': 7.2,
#    'idDireccVento': 3,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.4,
#    'humidade': 96.0,
#    'pressao': 1012.0},
#   '1200522': {'intensidadeVentoKM': 4.3,
#    'temperatura': 18.9,
#    'radiacao': 0.0,
#    'idDireccVento': 8,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.2,
#    'humidade': 81.0,
#    'pressao': 1019.9},
#   '6215360': {'intensidadeVentoKM': 28.8,
#    'temperatura': 15.5,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.2,
#    'intensidadeVento': 8.0,
#    'humidade': 100.0,
#    'pressao': 1012.9},
#   '1210577': {'intensidadeVentoKM': 21.6,
#    'temperatura': 16.6,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 6.0,
#    'humidade': 91.0,
#    'pressao': -99.0},
#   '7240919': {'intensidadeVentoKM': 24.1,
#    'temperatura': 15.4,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 6.7,
#    'humidade': 100.0,
#    'pressao': 1014.3},
#   '6213021': {'intensidadeVentoKM': 37.8,
#    'temperatura': 10.5,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 10.5,
#    'humidade': 98.0,
#    'pressao': -99.0},
#   '11217625': {'intensidadeVentoKM': 37.8,
#    'temperatura': 12.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 10.5,
#    'humidade': 69.0,
#    'pressao': -99.0},
#   '6214522': None,
#   '6214523': {'intensidadeVentoKM': -99.0,
#    'temperatura': -99.0,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': -99.0,
#    'intensidadeVento': -99.0,
#    'humidade': 89.0,
#    'pressao': -99.0},
#   '1210604': {'intensidadeVentoKM': 16.6,
#    'temperatura': 15.4,
#    'radiacao': 0.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.6,
#    'humidade': 90.0,
#    'pressao': 1009.9},
#   '11217645': {'intensidadeVentoKM': 14.0,
#    'temperatura': 13.2,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.9,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210606': {'intensidadeVentoKM': 20.9,
#    'temperatura': 9.7,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.8,
#    'humidade': 88.0,
#    'pressao': 1010.7},
#   '1210611': {'intensidadeVentoKM': 10.1,
#    'temperatura': 8.8,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.8,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210612': None,
#   '1210750': {'intensidadeVentoKM': 27.0,
#    'temperatura': 15.3,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.5,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210615': {'intensidadeVentoKM': 5.0,
#    'temperatura': 15.3,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.4,
#    'humidade': 83.0,
#    'pressao': -99.0},
#   '1210616': {'intensidadeVentoKM': 12.2,
#    'temperatura': 13.3,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.4,
#    'humidade': 83.0,
#    'pressao': 1011.0},
#   '1210619': {'intensidadeVentoKM': -99.0,
#    'temperatura': 11.2,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 98.0,
#    'pressao': -99.0},
#   '1210622': {'intensidadeVentoKM': 7.9,
#    'temperatura': 14.6,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.2,
#    'humidade': 90.0,
#    'pressao': -99.0},
#   '6210817': {'intensidadeVentoKM': 29.5,
#    'temperatura': 16.0,
#    'radiacao': -99.0,
#    'idDireccVento': 5,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 8.2,
#    'humidade': 94.0,
#    'pressao': 1013.2},
#   '1210630': {'intensidadeVentoKM': 1.8,
#    'temperatura': 11.7,
#    'radiacao': 0.0,
#    'idDireccVento': 8,
#    'precAcumulada': 0.5,
#    'intensidadeVento': 0.5,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '11217160': {'intensidadeVentoKM': 7.9,
#    'temperatura': -99.0,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.2,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210633': {'intensidadeVentoKM': 6.8,
#    'temperatura': 10.1,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.9,
#    'humidade': 89.0,
#    'pressao': -99.0},
#   '1210635': {'intensidadeVentoKM': 7.9,
#    'temperatura': 10.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.2,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '11217165': {'intensidadeVentoKM': 17.3,
#    'temperatura': -99.0,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.8,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1210643': {'intensidadeVentoKM': 8.3,
#    'temperatura': 13.3,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.3,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1210644': {'intensidadeVentoKM': 0.7,
#    'temperatura': 9.0,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.2,
#    'humidade': 92.0,
#    'pressao': -99.0},
#   '1210649': {'intensidadeVentoKM': 7.6,
#    'temperatura': 14.2,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.1,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210654': {'intensidadeVentoKM': 6.5,
#    'temperatura': 12.9,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.8,
#    'humidade': 78.0,
#    'pressao': 1011.8},
#   '1210655': {'intensidadeVentoKM': 2.5,
#    'temperatura': 12.0,
#    'radiacao': -99.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.7,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210657': {'intensidadeVentoKM': 3.6,
#    'temperatura': 12.9,
#    'radiacao': 0.1,
#    'idDireccVento': 3,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.0,
#    'humidade': 92.0,
#    'pressao': -99.0},
#   '1210663': {'intensidadeVentoKM': 10.1,
#    'temperatura': 11.4,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.8,
#    'humidade': 89.0,
#    'pressao': -99.0},
#   '1210666': {'intensidadeVentoKM': 15.5,
#    'temperatura': 10.5,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 4.3,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210669': {'intensidadeVentoKM': 4.3,
#    'temperatura': 14.1,
#    'radiacao': 0.0,
#    'idDireccVento': 1,
#    'precAcumulada': 0.3,
#    'intensidadeVento': 1.2,
#    'humidade': 93.0,
#    'pressao': -99.0},
#   '11217710': {'intensidadeVentoKM': -99.0,
#    'temperatura': 11.0,
#    'radiacao': 0.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210671': {'intensidadeVentoKM': 6.8,
#    'temperatura': 11.3,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.9,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '1210746': {'intensidadeVentoKM': 25.2,
#    'temperatura': 15.5,
#    'radiacao': 0.6,
#    'idDireccVento': 6,
#    'precAcumulada': 0.4,
#    'intensidadeVento': 7.0,
#    'humidade': 99.0,
#    'pressao': 1013.9},
#   '6210872': None,
#   '6212410': {'intensidadeVentoKM': 6.8,
#    'temperatura': 14.6,
#    'radiacao': -99.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.9,
#    'humidade': 93.0,
#    'pressao': -99.0},
#   '1210683': {'intensidadeVentoKM': 9.4,
#    'temperatura': 9.7,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 3.0,
#    'intensidadeVento': 2.6,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210685': {'intensidadeVentoKM': 10.1,
#    'temperatura': 13.3,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 1.5,
#    'intensidadeVento': 2.8,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1210686': {'intensidadeVentoKM': -99.0,
#    'temperatura': 10.7,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': -99.0,
#    'intensidadeVento': -99.0,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210687': {'intensidadeVentoKM': 10.4,
#    'temperatura': 13.1,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 6.8,
#    'intensidadeVento': 2.9,
#    'humidade': 98.0,
#    'pressao': -99.0},
#   '11217217': {'intensidadeVentoKM': 9.4,
#    'temperatura': 16.2,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.6,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '11217730': None,
#   '1240903': {'intensidadeVentoKM': -99.0,
#    'temperatura': 14.6,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1210697': {'intensidadeVentoKM': 6.1,
#    'temperatura': 15.6,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 1.7,
#    'intensidadeVento': 1.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210698': {'intensidadeVentoKM': 2.9,
#    'temperatura': 12.7,
#    'radiacao': -99.0,
#    'idDireccVento': 9,
#    'precAcumulada': 6.3,
#    'intensidadeVento': 0.8,
#    'humidade': 86.0,
#    'pressao': -99.0},
#   '1210702': {'intensidadeVentoKM': 9.4,
#    'temperatura': 15.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.6,
#    'humidade': 94.0,
#    'pressao': 1012.3},
#   '1210765': {'intensidadeVentoKM': 27.4,
#    'temperatura': 16.0,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.2,
#    'intensidadeVento': 7.6,
#    'humidade': 99.0,
#    'pressao': 1013.2},
#   '1210704': {'intensidadeVentoKM': 12.6,
#    'temperatura': 14.8,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.5,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210705': {'intensidadeVentoKM': 0.0,
#    'temperatura': 15.0,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.0,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1210707': {'intensidadeVentoKM': 1.8,
#    'temperatura': 15.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 3.7,
#    'intensidadeVento': 0.5,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1240916': None,
#   '1210713': {'intensidadeVentoKM': 15.1,
#    'temperatura': 15.1,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 4.2,
#    'humidade': 93.0,
#    'pressao': -99.0},
#   '1210767': {'intensidadeVentoKM': 21.6,
#    'temperatura': 16.1,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.3,
#    'intensidadeVento': 6.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210716': {'intensidadeVentoKM': 26.6,
#    'temperatura': 14.4,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 3.0,
#    'intensidadeVento': 7.4,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210718': {'intensidadeVentoKM': 11.9,
#    'temperatura': 15.7,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.6,
#    'intensidadeVento': 3.3,
#    'humidade': 92.0,
#    'pressao': 1013.1},
#   '1240929': None,
#   '1210724': {'intensidadeVentoKM': 9.7,
#    'temperatura': 16.0,
#    'radiacao': 1.6,
#    'idDireccVento': 6,
#    'precAcumulada': 3.7,
#    'intensidadeVento': 2.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210726': {'intensidadeVentoKM': 11.9,
#    'temperatura': 16.6,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.6,
#    'intensidadeVento': 3.3,
#    'humidade': 92.0,
#    'pressao': -99.0},
#   '11217255': None,
#   '1210729': {'intensidadeVentoKM': 9.4,
#    'temperatura': 16.7,
#    'radiacao': 13.0,
#    'idDireccVento': 7,
#    'precAcumulada': 2.2,
#    'intensidadeVento': 2.6,
#    'humidade': 95.0,
#    'pressao': -99.0},
#   '1210734': {'intensidadeVentoKM': 23.8,
#    'temperatura': 15.9,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 1.5,
#    'intensidadeVento': 6.6,
#    'humidade': 98.0,
#    'pressao': 1013.0},
#   '1210739': {'intensidadeVentoKM': 27.7,
#    'temperatura': 16.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.4,
#    'intensidadeVento': 7.7,
#    'humidade': 95.0,
#    'pressao': -99.0},
#   '1200501': {'intensidadeVentoKM': 19.4,
#    'temperatura': 16.9,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.4,
#    'humidade': 75.0,
#    'pressao': 1002.4},
#   '1200502': {'intensidadeVentoKM': 23.0,
#    'temperatura': 16.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 6.4,
#    'humidade': 91.0,
#    'pressao': 1002.3},
#   '1200504': {'intensidadeVentoKM': 27.4,
#    'temperatura': 16.6,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.6,
#    'humidade': 88.0,
#    'pressao': 1005.7},
#   '6214521': None,
#   '1200506': {'intensidadeVentoKM': 18.4,
#    'temperatura': 16.5,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.1,
#    'humidade': 95.0,
#    'pressao': 1006.3},
#   '1200507': None,
#   '1200510': {'intensidadeVentoKM': 19.1,
#    'temperatura': 16.1,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.3,
#    'humidade': 88.0,
#    'pressao': 1006.9},
#   '1200533': {'intensidadeVentoKM': 14.0,
#    'temperatura': 16.5,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 3.9,
#    'humidade': 93.0,
#    'pressao': 1017.6},
#   '1200512': {'intensidadeVentoKM': 25.9,
#    'temperatura': 16.0,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.2,
#    'humidade': 96.0,
#    'pressao': 1009.9},
#   '1200515': {'intensidadeVentoKM': 27.4,
#    'temperatura': 16.4,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.6,
#    'humidade': 95.0,
#    'pressao': 1011.6},
#   '1200521': {'intensidadeVentoKM': 2.2,
#    'temperatura': 17.8,
#    'radiacao': 0.0,
#    'idDireccVento': 8,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.6,
#    'humidade': 80.0,
#    'pressao': 1019.6},
#   '1210762': {'intensidadeVentoKM': 18.7,
#    'temperatura': 16.1,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 5.2,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1240971': {'intensidadeVentoKM': 0.7,
#    'temperatura': 18.7,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.2,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '1200524': {'intensidadeVentoKM': 1.4,
#    'temperatura': 17.4,
#    'radiacao': 0.0,
#    'idDireccVento': 8,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.4,
#    'humidade': 94.0,
#    'pressao': 1019.7},
#   '1210690': {'intensidadeVentoKM': 1.4,
#    'temperatura': 13.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 1.9,
#    'intensidadeVento': 0.4,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1210766': {'intensidadeVentoKM': 27.0,
#    'temperatura': 17.2,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 7.5,
#    'humidade': 92.0,
#    'pressao': -99.0},
#   '1210605': {'intensidadeVentoKM': 14.8,
#    'temperatura': 15.6,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.1,
#    'humidade': 76.0,
#    'pressao': -99.0},
#   '6210879': {'intensidadeVentoKM': 9.0,
#    'temperatura': 15.9,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.5,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210770': {'intensidadeVentoKM': 8.6,
#    'temperatura': 16.4,
#    'radiacao': 0.1,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.4,
#    'humidade': 95.0,
#    'pressao': -99.0},
#   '1240935': None,
#   '6213012': {'intensidadeVentoKM': 7.9,
#    'temperatura': 13.6,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 4.1,
#    'intensidadeVento': 2.2,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1210773': {'intensidadeVentoKM': 17.3,
#    'temperatura': 16.3,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.8,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '6213014': {'intensidadeVentoKM': 14.8,
#    'temperatura': 11.9,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 1.3,
#    'intensidadeVento': 4.1,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '6213015': None,
#   '6213016': None,
#   '6213017': {'intensidadeVentoKM': 4.7,
#    'temperatura': 12.5,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 1.2,
#    'intensidadeVento': 1.3,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213018': {'intensidadeVentoKM': -99.0,
#    'temperatura': 9.2,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': -99.0,
#    'intensidadeVento': -99.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213019': {'intensidadeVentoKM': 11.9,
#    'temperatura': 13.5,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 5.9,
#    'intensidadeVento': 3.3,
#    'humidade': 98.0,
#    'pressao': -99.0},
#   '6213020': {'intensidadeVentoKM': 7.2,
#    'temperatura': 11.0,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1200541': {'intensidadeVentoKM': 21.6,
#    'temperatura': 15.5,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.8,
#    'intensidadeVento': 6.0,
#    'humidade': 100.0,
#    'pressao': 1015.9},
#   '6213022': {'intensidadeVentoKM': 8.3,
#    'temperatura': 10.1,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.3,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '6213023': {'intensidadeVentoKM': 26.6,
#    'temperatura': 10.8,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 7.4,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213024': None,
#   '1200545': {'intensidadeVentoKM': 10.1,
#    'temperatura': 14.3,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.8,
#    'humidade': 99.0,
#    'pressao': 1011.4},
#   '1210776': {'intensidadeVentoKM': 20.5,
#    'temperatura': 17.1,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.5,
#    'intensidadeVento': 5.7,
#    'humidade': 89.0,
#    'pressao': -99.0},
#   '1200548': {'intensidadeVentoKM': 8.3,
#    'temperatura': 14.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 1.5,
#    'intensidadeVento': 2.3,
#    'humidade': -99.0,
#    'pressao': 1012.6},
#   '1210789': {'intensidadeVentoKM': 11.2,
#    'temperatura': 17.7,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.1,
#    'humidade': 87.0,
#    'pressao': -99.0},
#   '1210790': {'intensidadeVentoKM': 33.1,
#    'temperatura': -99.0,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 9.2,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1200551': {'intensidadeVentoKM': 8.6,
#    'temperatura': 14.1,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.4,
#    'humidade': 95.0,
#    'pressao': 1010.6},
#   '1200554': {'intensidadeVentoKM': 16.9,
#    'temperatura': 16.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.7,
#    'humidade': 98.0,
#    'pressao': 1018.0},
#   '6213011': None,
#   '1210866': {'intensidadeVentoKM': -99.0,
#    'temperatura': 15.7,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '1200558': {'intensidadeVentoKM': 26.3,
#    'temperatura': 15.3,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.3,
#    'humidade': 100.0,
#    'pressao': 1015.4},
#   '1200559': {'intensidadeVentoKM': 7.6,
#    'temperatura': 11.5,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.1,
#    'humidade': 100.0,
#    'pressao': 1011.8},
#   '1210800': {'intensidadeVentoKM': 5.4,
#    'temperatura': 11.6,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 2.8,
#    'intensidadeVento': 1.5,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1200562': {'intensidadeVentoKM': 19.4,
#    'temperatura': 14.7,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.4,
#    'humidade': 100.0,
#    'pressao': 1016.3},
#   '1210803': {'intensidadeVentoKM': 20.2,
#    'temperatura': 13.1,
#    'radiacao': 0.5,
#    'idDireccVento': 6,
#    'precAcumulada': 4.7,
#    'intensidadeVento': 5.6,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1210806': {'intensidadeVentoKM': 20.5,
#    'temperatura': 14.3,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.2,
#    'intensidadeVento': 5.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1200567': {'intensidadeVentoKM': 2.5,
#    'temperatura': 11.3,
#    'radiacao': 0.0,
#    'idDireccVento': 4,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.7,
#    'humidade': 100.0,
#    'pressao': 1011.8},
#   '1200568': {'intensidadeVentoKM': -99.0,
#    'temperatura': 7.7,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 7.3,
#    'intensidadeVento': -99.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1240820': None,
#   '1200570': {'intensidadeVentoKM': 18.7,
#    'temperatura': 14.2,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 3.9,
#    'intensidadeVento': 5.2,
#    'humidade': 100.0,
#    'pressao': 1012.4},
#   '1210783': {'intensidadeVentoKM': 16.9,
#    'temperatura': 17.1,
#    'radiacao': 0.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.7,
#    'humidade': 88.0,
#    'pressao': -99.0},
#   '1210812': {'intensidadeVentoKM': 9.0,
#    'temperatura': 16.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 3.8,
#    'intensidadeVento': 2.5,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '1200575': {'intensidadeVentoKM': 11.2,
#    'temperatura': 9.9,
#    'radiacao': 0.0,
#    'idDireccVento': 4,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.1,
#    'humidade': 88.0,
#    'pressao': 1012.2},
#   '1200576': {'intensidadeVentoKM': 11.9,
#    'temperatura': 10.7,
#    'radiacao': -99.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.3,
#    'humidade': 91.0,
#    'pressao': 1012.0},
#   '1200579': {'intensidadeVentoKM': 32.8,
#    'temperatura': 15.7,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.3,
#    'intensidadeVento': 9.1,
#    'humidade': 96.0,
#    'pressao': 1013.8},
#   '1210824': {'intensidadeVentoKM': 16.9,
#    'temperatura': 15.9,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.7,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1210826': {'intensidadeVentoKM': 24.1,
#    'temperatura': 16.3,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 6.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1200531': {'intensidadeVentoKM': 21.6,
#    'temperatura': 15.3,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.2,
#    'intensidadeVento': 6.0,
#    'humidade': 100.0,
#    'pressao': 1013.2},
#   '1210835': {'intensidadeVentoKM': 18.0,
#    'temperatura': 15.2,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.0,
#    'humidade': 90.0,
#    'pressao': -99.0},
#   '1200511': {'intensidadeVentoKM': 24.8,
#    'temperatura': 15.6,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.9,
#    'intensidadeVento': 6.9,
#    'humidade': 96.0,
#    'pressao': 1007.1},
#   '1210837': {'intensidadeVentoKM': 16.6,
#    'temperatura': 14.9,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.6,
#    'humidade': 91.0,
#    'pressao': -99.0},
#   '1210863': {'intensidadeVentoKM': 11.2,
#    'temperatura': 14.4,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.1,
#    'humidade': 90.0,
#    'pressao': -99.0},
#   '1210840': {'intensidadeVentoKM': 20.2,
#    'temperatura': 14.8,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.6,
#    'humidade': 91.0,
#    'pressao': -99.0},
#   '1210788': {'intensidadeVentoKM': 9.7,
#    'temperatura': 16.7,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '11217370': {'intensidadeVentoKM': 10.4,
#    'temperatura': 11.6,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.9,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6213621': {'intensidadeVentoKM': 36.4,
#    'temperatura': 12.8,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 1.2,
#    'intensidadeVento': 10.1,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '11217372': {'intensidadeVentoKM': 34.9,
#    'temperatura': 13.4,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.4,
#    'intensidadeVento': 9.7,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '11217225': {'intensidadeVentoKM': 23.0,
#    'temperatura': 15.3,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 6.4,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210847': {'intensidadeVentoKM': 21.6,
#    'temperatura': 15.5,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 6.0,
#    'humidade': 90.0,
#    'pressao': -99.0},
#   '1210848': {'intensidadeVentoKM': 21.2,
#    'temperatura': 15.6,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.9,
#    'humidade': 92.0,
#    'pressao': -99.0},
#   '1210744': {'intensidadeVentoKM': 27.0,
#    'temperatura': 16.6,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 1.0,
#    'intensidadeVento': 7.5,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1240546': {'intensidadeVentoKM': 16.9,
#    'temperatura': 14.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.7,
#    'humidade': 100.0,
#    'pressao': 1010.5},
#   '1210851': {'intensidadeVentoKM': 13.3,
#    'temperatura': 15.6,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.7,
#    'humidade': 87.0,
#    'pressao': 1015.7},
#   '6213013': {'intensidadeVentoKM': 13.3,
#    'temperatura': 9.6,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 3.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213611': {'intensidadeVentoKM': 6.5,
#    'temperatura': 15.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 9.6,
#    'intensidadeVento': 1.8,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6213612': {'intensidadeVentoKM': 4.0,
#    'temperatura': 14.1,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.1,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6213613': {'intensidadeVentoKM': 6.1,
#    'temperatura': 14.5,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 1.7,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6213614': {'intensidadeVentoKM': 6.5,
#    'temperatura': 14.1,
#    'radiacao': -99.0,
#    'idDireccVento': 5,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 1.8,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213615': {'intensidadeVentoKM': 2.9,
#    'temperatura': 15.6,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.8,
#    'humidade': 95.0,
#    'pressao': -99.0},
#   '6213616': {'intensidadeVentoKM': 7.9,
#    'temperatura': 14.7,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.2,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213617': {'intensidadeVentoKM': 9.0,
#    'temperatura': 15.3,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 2.9,
#    'intensidadeVento': 2.5,
#    'humidade': 93.0,
#    'pressao': -99.0},
#   '6213618': None,
#   '6213619': {'intensidadeVentoKM': 9.7,
#    'temperatura': 15.5,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 5.6,
#    'intensidadeVento': 2.7,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '6213620': {'intensidadeVentoKM': 5.8,
#    'temperatura': 14.3,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 2.6,
#    'intensidadeVento': 1.6,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1210864': {'intensidadeVentoKM': 14.0,
#    'temperatura': 15.8,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.9,
#    'humidade': 91.0,
#    'pressao': -99.0},
#   '1240566': {'intensidadeVentoKM': 4.7,
#    'temperatura': 12.6,
#    'radiacao': -99.0,
#    'idDireccVento': 4,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.3,
#    'humidade': 87.0,
#    'pressao': -99.0},
#   '1210874': {'intensidadeVentoKM': 11.9,
#    'temperatura': 15.7,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.3,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210878': {'intensidadeVentoKM': 7.9,
#    'temperatura': 16.3,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.2,
#    'humidade': 95.0,
#    'pressao': 1017.7}},
#  '2023-03-09T07:00': {'1210881': {'intensidadeVentoKM': 18.0,
#    'temperatura': 16.8,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.2,
#    'intensidadeVento': 5.0,
#    'humidade': 96.0,
#    'pressao': 1017.4},
#   '1210883': {'intensidadeVentoKM': 19.1,
#    'temperatura': 16.3,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 1.4,
#    'intensidadeVento': 5.3,
#    'humidade': 97.0,
#    'pressao': 1018.4},
#   '1210865': None,
#   '11217430': {'intensidadeVentoKM': 21.2,
#    'temperatura': 15.3,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.9,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6212121': {'intensidadeVentoKM': 15.1,
#    'temperatura': 11.9,
#    'radiacao': 5.4,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.2,
#    'humidade': 91.0,
#    'pressao': 1009.0},
#   '6212122': {'intensidadeVentoKM': 9.4,
#    'temperatura': 13.2,
#    'radiacao': 3.6,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.6,
#    'humidade': 90.0,
#    'pressao': 1011.0},
#   '1210907': None,
#   '6212124': {'intensidadeVentoKM': 19.4,
#    'temperatura': 12.6,
#    'radiacao': 4.2,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.4,
#    'humidade': 95.0,
#    'pressao': 1011.5},
#   '6212125': None,
#   '6212126': {'intensidadeVentoKM': 27.0,
#    'temperatura': 14.4,
#    'radiacao': 3.6,
#    'idDireccVento': 5,
#    'precAcumulada': 0.2,
#    'intensidadeVento': 7.5,
#    'humidade': 90.0,
#    'pressao': 1010.5},
#   '1200560': {'intensidadeVentoKM': 21.6,
#    'temperatura': 10.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 6.0,
#    'humidade': 100.0,
#    'pressao': 1013.7},
#   '1240610': {'intensidadeVentoKM': -99.0,
#    'temperatura': 14.4,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 94.0,
#    'pressao': -99.0},
#   '1210867': {'intensidadeVentoKM': 15.5,
#    'temperatura': 16.7,
#    'radiacao': 0.6,
#    'idDireccVento': 6,
#    'precAcumulada': 0.2,
#    'intensidadeVento': 4.3,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210632': {'intensidadeVentoKM': 16.6,
#    'temperatura': 10.3,
#    'radiacao': -99.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.6,
#    'humidade': 89.0,
#    'pressao': -99.0},
#   '1210932': {'intensidadeVentoKM': 10.1,
#    'temperatura': 15.7,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 2.8,
#    'humidade': 85.0,
#    'pressao': -99.0},
#   '1210747': {'intensidadeVentoKM': -99.0,
#    'temperatura': 16.3,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 95.0,
#    'pressao': -99.0},
#   '1200535': {'intensidadeVentoKM': 25.6,
#    'temperatura': 15.6,
#    'radiacao': 0.9,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.1,
#    'humidade': 100.0,
#    'pressao': 1014.8},
#   '1210721': {'intensidadeVentoKM': 22.7,
#    'temperatura': 12.8,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 6.3,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '1210956': {'intensidadeVentoKM': 4.7,
#    'temperatura': 20.1,
#    'radiacao': 0.5,
#    'idDireccVento': 9,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.3,
#    'humidade': 75.0,
#    'pressao': -99.0},
#   '1210637': {'intensidadeVentoKM': 25.6,
#    'temperatura': 9.7,
#    'radiacao': 2.2,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.1,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210960': {'intensidadeVentoKM': 3.6,
#    'temperatura': 17.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.0,
#    'humidade': 91.0,
#    'pressao': 1020.0},
#   '1210965': {'intensidadeVentoKM': -99.0,
#    'temperatura': 15.0,
#    'radiacao': 0.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 84.0,
#    'pressao': -99.0},
#   '1210967': {'intensidadeVentoKM': -99.0,
#    'temperatura': 16.1,
#    'radiacao': 0.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 84.0,
#    'pressao': -99.0},
#   '1210970': {'intensidadeVentoKM': -99.0,
#    'temperatura': 8.8,
#    'radiacao': 0.6,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210972': {'intensidadeVentoKM': 5.8,
#    'temperatura': 12.1,
#    'radiacao': 0.0,
#    'idDireccVento': 8,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.6,
#    'humidade': 86.0,
#    'pressao': -99.0},
#   '1210973': {'intensidadeVentoKM': 16.6,
#    'temperatura': 9.2,
#    'radiacao': 0.0,
#    'idDireccVento': 9,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.6,
#    'humidade': 86.0,
#    'pressao': -99.0},
#   '1210974': {'intensidadeVentoKM': -99.0,
#    'temperatura': 6.7,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210975': {'intensidadeVentoKM': -99.0,
#    'temperatura': 12.4,
#    'radiacao': 184.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1210976': {'intensidadeVentoKM': 4.0,
#    'temperatura': 13.4,
#    'radiacao': 0.1,
#    'idDireccVento': 1,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.1,
#    'humidade': 91.0,
#    'pressao': -99.0},
#   '1210977': {'intensidadeVentoKM': 5.0,
#    'temperatura': 17.3,
#    'radiacao': 0.0,
#    'idDireccVento': 1,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.4,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '1210978': {'intensidadeVentoKM': 2.9,
#    'temperatura': 18.2,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.8,
#    'humidade': 81.0,
#    'pressao': -99.0},
#   '1240675': {'intensidadeVentoKM': -99.0,
#    'temperatura': 11.6,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 95.0,
#    'pressao': -99.0},
#   '1210980': {'intensidadeVentoKM': 27.7,
#    'temperatura': 13.0,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '11217510': {'intensidadeVentoKM': 66.6,
#    'temperatura': 11.1,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.6,
#    'intensidadeVento': 18.5,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210984': {'intensidadeVentoKM': -99.0,
#    'temperatura': 16.0,
#    'radiacao': 1.7,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 92.0,
#    'pressao': -99.0},
#   '1210986': {'intensidadeVentoKM': 0.4,
#    'temperatura': 18.7,
#    'radiacao': 0.0,
#    'idDireccVento': 2,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.1,
#    'humidade': 90.0,
#    'pressao': 1019.8},
#   '1210987': {'intensidadeVentoKM': 1.4,
#    'temperatura': 14.6,
#    'radiacao': 0.3,
#    'idDireccVento': 8,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.4,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210990': {'intensidadeVentoKM': 12.2,
#    'temperatura': 16.5,
#    'radiacao': 0.2,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.4,
#    'humidade': 97.0,
#    'pressao': 1019.9},
#   '1200571': {'intensidadeVentoKM': 17.3,
#    'temperatura': 11.9,
#    'radiacao': 0.7,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.8,
#    'humidade': 100.0,
#    'pressao': 1015.5},
#   '5210758': {'intensidadeVentoKM': 11.9,
#    'temperatura': 16.1,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.3,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210513': {'intensidadeVentoKM': 6.5,
#    'temperatura': 16.2,
#    'radiacao': 0.8,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.8,
#    'humidade': 95.0,
#    'pressao': -99.0},
#   '1210520': None,
#   '6212123': {'intensidadeVentoKM': 6.5,
#    'temperatura': 13.3,
#    'radiacao': 7.8,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.8,
#    'humidade': 93.0,
#    'pressao': 1012.0},
#   '1200522': {'intensidadeVentoKM': 3.2,
#    'temperatura': 19.0,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.9,
#    'humidade': 79.0,
#    'pressao': 1020.3},
#   '6215360': {'intensidadeVentoKM': 17.3,
#    'temperatura': 15.1,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.8,
#    'humidade': 100.0,
#    'pressao': 1013.8},
#   '1210577': {'intensidadeVentoKM': 18.7,
#    'temperatura': 16.2,
#    'radiacao': 0.5,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 5.2,
#    'humidade': 98.0,
#    'pressao': -99.0},
#   '7240919': {'intensidadeVentoKM': 15.5,
#    'temperatura': 14.9,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.3,
#    'humidade': 100.0,
#    'pressao': 1015.5},
#   '6213021': None,
#   '11217625': {'intensidadeVentoKM': 33.8,
#    'temperatura': 11.5,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 9.4,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6214522': None,
#   '6214523': {'intensidadeVentoKM': -99.0,
#    'temperatura': -99.0,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': -99.0,
#    'intensidadeVento': -99.0,
#    'humidade': 90.0,
#    'pressao': -99.0},
#   '1210604': {'intensidadeVentoKM': 14.4,
#    'temperatura': 15.3,
#    'radiacao': 0.1,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.0,
#    'humidade': 83.0,
#    'pressao': 1009.1},
#   '11217645': {'intensidadeVentoKM': 23.4,
#    'temperatura': 13.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 6.5,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1210606': {'intensidadeVentoKM': 19.4,
#    'temperatura': 8.8,
#    'radiacao': 0.4,
#    'idDireccVento': 5,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 5.4,
#    'humidade': 86.0,
#    'pressao': 1010.5},
#   '1210611': {'intensidadeVentoKM': 15.8,
#    'temperatura': 7.4,
#    'radiacao': 1.7,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.4,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1210612': None,
#   '1210750': {'intensidadeVentoKM': 25.6,
#    'temperatura': 14.8,
#    'radiacao': 1.3,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.1,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210615': {'intensidadeVentoKM': 9.4,
#    'temperatura': 14.8,
#    'radiacao': 0.3,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.6,
#    'humidade': 84.0,
#    'pressao': -99.0},
#   '1210616': {'intensidadeVentoKM': 15.8,
#    'temperatura': 12.6,
#    'radiacao': 1.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.4,
#    'humidade': 77.0,
#    'pressao': 1010.8},
#   '1210619': {'intensidadeVentoKM': -99.0,
#    'temperatura': 10.2,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.1,
#    'intensidadeVento': -99.0,
# ...
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.6,
#    'humidade': 96.0,
#    'pressao': 1006.2},
#   '1200507': None,
#   '1200510': {'intensidadeVentoKM': 18.0,
#    'temperatura': 15.7,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.0,
#    'humidade': 90.0,
#    'pressao': 1006.4},
#   '1200533': {'intensidadeVentoKM': 20.5,
#    'temperatura': 16.6,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 5.7,
#    'humidade': 92.0,
#    'pressao': 1016.9},
#   '1200512': {'intensidadeVentoKM': 21.6,
#    'temperatura': 15.8,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 6.0,
#    'humidade': 97.0,
#    'pressao': 1010.0},
#   '1200515': {'intensidadeVentoKM': 20.2,
#    'temperatura': 16.2,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.6,
#    'humidade': 95.0,
#    'pressao': 1011.6},
#   '1200521': {'intensidadeVentoKM': 0.0,
#    'temperatura': 17.5,
#    'radiacao': 0.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.0,
#    'humidade': 82.0,
#    'pressao': 1019.4},
#   '1210762': {'intensidadeVentoKM': 8.3,
#    'temperatura': 15.7,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.3,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1240971': {'intensidadeVentoKM': 4.7,
#    'temperatura': 18.6,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.3,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1200524': {'intensidadeVentoKM': 12.6,
#    'temperatura': 17.7,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.5,
#    'humidade': 92.0,
#    'pressao': 1019.4},
#   '1210690': {'intensidadeVentoKM': 2.5,
#    'temperatura': 12.9,
#    'radiacao': 0.0,
#    'idDireccVento': 8,
#    'precAcumulada': 0.4,
#    'intensidadeVento': 0.7,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1210766': {'intensidadeVentoKM': 15.1,
#    'temperatura': 17.0,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.2,
#    'humidade': 91.0,
#    'pressao': -99.0},
#   '1210605': {'intensidadeVentoKM': 13.0,
#    'temperatura': 14.6,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.6,
#    'humidade': 82.0,
#    'pressao': -99.0},
#   '6210879': {'intensidadeVentoKM': 19.4,
#    'temperatura': 15.8,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 1.5,
#    'intensidadeVento': 5.4,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210770': {'intensidadeVentoKM': 11.2,
#    'temperatura': 17.1,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.1,
#    'humidade': 88.0,
#    'pressao': -99.0},
#   '1240935': None,
#   '6213012': {'intensidadeVentoKM': 9.0,
#    'temperatura': 13.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.5,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1210773': {'intensidadeVentoKM': 8.3,
#    'temperatura': 16.0,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.3,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '6213014': {'intensidadeVentoKM': 22.7,
#    'temperatura': 11.5,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 6.3,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '6213015': None,
#   '6213016': None,
#   '6213017': {'intensidadeVentoKM': 11.9,
#    'temperatura': 12.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.3,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6213018': {'intensidadeVentoKM': -99.0,
#    'temperatura': 8.0,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': -99.0,
#    'intensidadeVento': -99.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213019': {'intensidadeVentoKM': 10.1,
#    'temperatura': 13.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 2.8,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '6213020': {'intensidadeVentoKM': 10.8,
#    'temperatura': 10.6,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 3.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1200541': {'intensidadeVentoKM': 17.6,
#    'temperatura': 15.6,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 4.9,
#    'humidade': 100.0,
#    'pressao': 1015.7},
#   '6213022': {'intensidadeVentoKM': 9.4,
#    'temperatura': 9.8,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.6,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '6213023': {'intensidadeVentoKM': 27.7,
#    'temperatura': 9.9,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 7.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213024': None,
#   '1200545': {'intensidadeVentoKM': 12.6,
#    'temperatura': 14.0,
#    'radiacao': 0.4,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.5,
#    'humidade': 99.0,
#    'pressao': 1011.4},
#   '1210776': {'intensidadeVentoKM': 18.4,
#    'temperatura': 16.8,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.1,
#    'humidade': 92.0,
#    'pressao': -99.0},
#   '1200548': {'intensidadeVentoKM': 10.4,
#    'temperatura': 14.1,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.9,
#    'humidade': -99.0,
#    'pressao': 1013.0},
#   '1210789': {'intensidadeVentoKM': 10.8,
#    'temperatura': 17.3,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 3.6,
#    'intensidadeVento': 3.0,
#    'humidade': 93.0,
#    'pressao': -99.0},
#   '1210790': {'intensidadeVentoKM': 31.0,
#    'temperatura': -99.0,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 3.5,
#    'intensidadeVento': 8.6,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1200551': {'intensidadeVentoKM': 7.2,
#    'temperatura': 13.8,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 2.0,
#    'humidade': 95.0,
#    'pressao': 1010.6},
#   '1200554': {'intensidadeVentoKM': 16.9,
#    'temperatura': 16.5,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.7,
#    'humidade': 100.0,
#    'pressao': 1017.5},
#   '6213011': None,
#   '1210866': {'intensidadeVentoKM': -99.0,
#    'temperatura': 16.0,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.0,
#    'intensidadeVento': -99.0,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1200558': {'intensidadeVentoKM': 23.8,
#    'temperatura': 15.0,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 3.1,
#    'intensidadeVento': 6.6,
#    'humidade': 100.0,
#    'pressao': 1014.8},
#   '1200559': {'intensidadeVentoKM': 9.7,
#    'temperatura': 11.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.7,
#    'humidade': 100.0,
#    'pressao': 1012.1},
#   '1210800': {'intensidadeVentoKM': 11.2,
#    'temperatura': 10.7,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 4.0,
#    'intensidadeVento': 3.1,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '1200562': {'intensidadeVentoKM': 20.2,
#    'temperatura': 14.6,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.6,
#    'humidade': 100.0,
#    'pressao': 1015.5},
#   '1210803': {'intensidadeVentoKM': 14.4,
#    'temperatura': 13.4,
#    'radiacao': 14.3,
#    'idDireccVento': 5,
#    'precAcumulada': 7.5,
#    'intensidadeVento': 4.0,
#    'humidade': 98.0,
#    'pressao': -99.0},
#   '1210806': {'intensidadeVentoKM': 22.0,
#    'temperatura': 14.0,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 6.1,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1200567': {'intensidadeVentoKM': 4.0,
#    'temperatura': 11.3,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.1,
#    'humidade': 100.0,
#    'pressao': 1011.6},
#   '1200568': {'intensidadeVentoKM': -99.0,
#    'temperatura': 6.9,
#    'radiacao': -99.0,
#    'idDireccVento': 0,
#    'precAcumulada': 2.0,
#    'intensidadeVento': -99.0,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1240820': None,
#   '1200570': {'intensidadeVentoKM': 14.4,
#    'temperatura': 13.8,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 4.0,
#    'intensidadeVento': 4.0,
#    'humidade': 100.0,
#    'pressao': 1012.0},
#   '1210783': {'intensidadeVentoKM': 14.4,
#    'temperatura': 16.7,
#    'radiacao': 0.0,
#    'idDireccVento': 0,
#    'precAcumulada': 0.5,
#    'intensidadeVento': 4.0,
#    'humidade': 94.0,
#    'pressao': -99.0},
#   '1210812': {'intensidadeVentoKM': 6.5,
#    'temperatura': 16.1,
#    'radiacao': -99.0,
#    'idDireccVento': 7,
#    'precAcumulada': 1.4,
#    'intensidadeVento': 1.8,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1200575': {'intensidadeVentoKM': 2.9,
#    'temperatura': 9.6,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 0.8,
#    'humidade': 90.0,
#    'pressao': 1011.6},
#   '1200576': {'intensidadeVentoKM': 5.8,
#    'temperatura': 10.1,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.6,
#    'humidade': 95.0,
#    'pressao': 1011.6},
#   '1200579': {'intensidadeVentoKM': 28.4,
#    'temperatura': 15.7,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.9,
#    'humidade': 92.0,
#    'pressao': 1013.8},
#   '1210824': {'intensidadeVentoKM': 22.7,
#    'temperatura': 16.1,
#    'radiacao': 1.2,
#    'idDireccVento': 6,
#    'precAcumulada': 1.0,
#    'intensidadeVento': 6.3,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '1210826': {'intensidadeVentoKM': 19.1,
#    'temperatura': 16.0,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.3,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1200531': {'intensidadeVentoKM': 25.2,
#    'temperatura': 15.1,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.0,
#    'humidade': 100.0,
#    'pressao': 1013.3},
#   '1210835': {'intensidadeVentoKM': 17.6,
#    'temperatura': 14.9,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.9,
#    'humidade': 92.0,
#    'pressao': -99.0},
#   '1200511': {'intensidadeVentoKM': 20.2,
#    'temperatura': 15.4,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.6,
#    'humidade': 97.0,
#    'pressao': 1007.7},
#   '1210837': {'intensidadeVentoKM': 16.9,
#    'temperatura': 14.7,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.4,
#    'intensidadeVento': 4.7,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '1210863': {'intensidadeVentoKM': 9.4,
#    'temperatura': 14.5,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.6,
#    'humidade': 91.0,
#    'pressao': -99.0},
#   '1210840': None,
#   '1210788': {'intensidadeVentoKM': 15.1,
#    'temperatura': 16.2,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 4.3,
#    'intensidadeVento': 4.2,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '11217370': {'intensidadeVentoKM': 11.2,
#    'temperatura': 12.1,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.1,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6213621': {'intensidadeVentoKM': 26.3,
#    'temperatura': 11.9,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 7.3,
#    'humidade': -99.0,
#    'pressao': -99.0},
#   '11217372': {'intensidadeVentoKM': 33.1,
#    'temperatura': 13.4,
#    'radiacao': 0.0,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 9.2,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '11217225': {'intensidadeVentoKM': 20.5,
#    'temperatura': 15.2,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.7,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210847': {'intensidadeVentoKM': 19.8,
#    'temperatura': 15.2,
#    'radiacao': 0.2,
#    'idDireccVento': 6,
#    'precAcumulada': 1.2,
#    'intensidadeVento': 5.5,
#    'humidade': 94.0,
#    'pressao': -99.0},
#   '1210848': {'intensidadeVentoKM': 19.8,
#    'temperatura': 15.4,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.9,
#    'intensidadeVento': 5.5,
#    'humidade': 94.0,
#    'pressao': -99.0},
#   '1210744': {'intensidadeVentoKM': 19.8,
#    'temperatura': 16.7,
#    'radiacao': 4.1,
#    'idDireccVento': 7,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 5.5,
#    'humidade': 94.0,
#    'pressao': -99.0},
#   '1240546': {'intensidadeVentoKM': 13.3,
#    'temperatura': 14.2,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.7,
#    'humidade': 100.0,
#    'pressao': 1010.5},
#   '1210851': {'intensidadeVentoKM': 14.4,
#    'temperatura': 15.3,
#    'radiacao': 0.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.0,
#    'humidade': 90.0,
#    'pressao': 1015.0},
#   '6213013': {'intensidadeVentoKM': 19.4,
#    'temperatura': 8.8,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 5.4,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6213611': {'intensidadeVentoKM': 10.8,
#    'temperatura': 15.0,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.3,
#    'intensidadeVento': 3.0,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6213612': {'intensidadeVentoKM': 5.0,
#    'temperatura': 13.9,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.4,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213613': {'intensidadeVentoKM': 8.6,
#    'temperatura': 14.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 2.4,
#    'humidade': 99.0,
#    'pressao': -99.0},
#   '6213614': {'intensidadeVentoKM': 9.0,
#    'temperatura': 14.3,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': -99.0,
#    'intensidadeVento': 2.5,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213615': {'intensidadeVentoKM': 3.6,
#    'temperatura': 15.3,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.0,
#    'humidade': 95.0,
#    'pressao': -99.0},
#   '6213616': {'intensidadeVentoKM': 2.2,
#    'temperatura': 14.6,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.2,
#    'intensidadeVento': 0.6,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '6213617': {'intensidadeVentoKM': 7.2,
#    'temperatura': 15.2,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 2.0,
#    'humidade': 93.0,
#    'pressao': -99.0},
#   '6213618': None,
#   '6213619': {'intensidadeVentoKM': 9.7,
#    'temperatura': 15.1,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.2,
#    'intensidadeVento': 2.7,
#    'humidade': 96.0,
#    'pressao': -99.0},
#   '6213620': {'intensidadeVentoKM': 9.0,
#    'temperatura': 14.0,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 2.5,
#    'humidade': 97.0,
#    'pressao': -99.0},
#   '1210864': {'intensidadeVentoKM': 17.6,
#    'temperatura': 15.9,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 4.9,
#    'humidade': 92.0,
#    'pressao': -99.0},
#   '1240566': {'intensidadeVentoKM': 4.3,
#    'temperatura': 12.6,
#    'radiacao': -99.0,
#    'idDireccVento': 5,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 1.2,
#    'humidade': 86.0,
#    'pressao': -99.0},
#   '1210874': {'intensidadeVentoKM': 11.5,
#    'temperatura': 15.7,
#    'radiacao': -99.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.0,
#    'intensidadeVento': 3.2,
#    'humidade': 100.0,
#    'pressao': -99.0},
#   '1210878': {'intensidadeVentoKM': 10.8,
#    'temperatura': 16.4,
#    'radiacao': 0.0,
#    'idDireccVento': 6,
#    'precAcumulada': 0.1,
#    'intensidadeVento': 3.0,
#    'humidade': 95.0,
#    'pressao': 1017.0}}}

# %%
obs_df = pd.DataFrame()
obs_df = pd.concat({k: pd.DataFrame(v).T for k, v in obs_dict.items()}, axis=0)
obs_df.reset_index(inplace=True)
obs_df['level_1'] = obs_df['level_1'].astype('int64')
obs_df.rename(columns={'level_0': 'date', 'level_1': 'id'}, inplace=True)
obs_df.head()
# Out:
#                date        id intensidadeVentoKM temperatura radiacao  \
# 0  2023-03-09T01:00   1210881                8.6        16.5    -99.0
# 1  2023-03-09T01:00   1210883                8.3        15.9    -99.0
# 2  2023-03-09T01:00   1210865               None        None     None
# 3  2023-03-09T01:00  11217430               18.7        14.6      0.0
# 4  2023-03-09T01:00   6212121               12.2        12.6      6.6
#
#   idDireccVento precAcumulada intensidadeVento humidade pressao
# 0           6.0           0.0              2.4     94.0  1017.7
# 1           6.0           0.0              2.3     95.0  1018.6
# 2          None          None             None     None    None
# 3           7.0           0.0              5.2     99.0   -99.0
# 4           6.0           0.0              3.4     92.0  1009.0

# %%
obs_df = obs_df.merge(idstations_df, on='id')

# %%
# obs_df.head()
metrics = ['intensidadeVentoKM', 'temperatura', 'radiacao', 'idDireccVento', 
           'precAcumulada',	'intensidadeVento',	'humidade',	'pressao']
obs_df.dropna(subset=metrics)
obs_df.to_csv('./data/obs_outdated.csv')

# %%
obs_df['radiacao'].unique()
# Out:
# array([-99.0, None, 0.0, ..., 2876.3, 1685.5, 576.1], dtype=object)

# %%
obs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4728 entries, 0 to 4727
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                4728 non-null   object
#  1   id                  4728 non-null   int64
#  2   intensidadeVentoKM  4205 non-null   object
#  3   temperatura         4205 non-null   object
#  4   radiacao            4205 non-null   object
#  5   idDireccVento       4205 non-null   object
#  6   precAcumulada       4205 non-null   object
#  7   intensidadeVento    4205 non-null   object
#  8   humidade            4205 non-null   object
#  9   pressao             4205 non-null   object
#  10  local               4728 non-null   object
#  11  lon                 4728 non-null   float64
#  12  lat                 4728 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 517.1+ KB

# %%
obs_df['humidade'] = obs_df['humidade'].astype('float')

# %%
temp_df = obs_df[obs_df['id'] == 1210881]
temp = px.bar(temp_df, 'date', 'temperatura',
              color='humidade')

temp.show()

# %%
app = JupyterDash(
    __name__,
    external_stylesheets=[dbc.themes.FLATLY, dbc_css],
    meta_tags=[
        dict(
            name="viewport",
            content="width=device-width, initial-scale=1.0",
        ),
    ],
)

# %%
dropdown = dcc.Dropdown(
    id='dropdown',
    options=idstations_df['local'],
    value='Lisboa, Amoreiras (LFCL)'
)

graph = dcc.Graph(id='barplot')

app.layout = dbc.Container(id='container', class_name='dbc',
                           children=[
                               dbc.Col([
                                   dropdown,
                                   graph,
                               ])
                           ]
                           )

# %%
@app.callback(Output('barplot', 'figure'),
              [Input('dropdown', 'value')])
def location(value):
    df = obs_df[obs_df['local'] == value]
    fig = px.bar(df, 'date', 'temperatura', color='humidade')
    return fig

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash app running on http://127.0.0.1:8050/

# %%
# Out:
# Dash app running on http://127.0.0.1:8050/

# %%
obs_df[obs_df['localEstacao'] == 'Amadora'].shape
# Out:
# (24, 12)
